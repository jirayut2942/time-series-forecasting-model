# %%
# Data
from pandas import DataFrame
import pandas as pd
import datetime 
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib import pyplot
import sys
import pytz
# from connectdb import engine

# Model LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
import math
from sklearn.metrics import mean_squared_error

# %%
from sqlalchemy import create_engine
# Mypc--Base
user = 'root'
passw = 'MTIzNDVhcm0='
host =  'localhost'  
port = 3306 
database = 'stocks_db'

engine = create_engine('mysql+pymysql://' + user + ':' + passw + '@' + host + ':' + str(port) + '/' + database , echo=False)
print(engine)
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/stocks_db)

# %%
sql = """ select * FROM  stocks_db.SET50  WHERE Symbols = "ADVANC.BK"  AND Date BETWEEN '2015-01-01' AND '2020-12-01'  """ 
data = pd.read_sql_query(sql, engine)
data
# Out:
#            Date    Symbols   Open   High    Low  Close   Adj Close      Volume
# 0    2015-01-05  ADVANC.BK  252.0  254.0  247.0  249.0  190.217331   5232400.0
# 1    2015-01-06  ADVANC.BK  246.0  250.0  245.0  247.0  188.689468   4386200.0
# 2    2015-01-07  ADVANC.BK  246.0  253.0  240.0  253.0  193.273026  11060300.0
# 3    2015-01-08  ADVANC.BK  251.0  252.0  248.0  250.0  190.981247   6530700.0
# 4    2015-01-09  ADVANC.BK  251.0  251.0  248.0  248.0  189.453384   4615500.0
# ...         ...        ...    ...    ...    ...    ...         ...         ...
# 1439 2020-11-25  ADVANC.BK  178.5  179.5  175.5  177.0  177.000000  15608500.0
# 1440 2020-11-26  ADVANC.BK  177.5  179.5  177.0  178.5  178.500000  12646400.0
# 1441 2020-11-27  ADVANC.BK  178.0  180.5  178.0  179.5  179.500000  10346100.0
# 1442 2020-11-30  ADVANC.BK  179.0  180.0  175.5  175.5  175.500000  20143400.0
# 1443 2020-12-01  ADVANC.BK  176.5  179.5  176.5  178.0  178.000000  12453300.0
#
# [1444 rows x 8 columns]

# %%
data
df_close =  data.reset_index()['Close']
df_close
plt.plot(df_close)
plt.title("Close price")
plt.show()

# %%
# trans -- 0,1
scaler=MinMaxScaler(feature_range=(0,1))
data1=scaler.fit_transform(np.array(df_close).reshape(-1,1))
plt.plot(data1)

# %%
train_size =  int(len(data1)*0.65)
test_size = len(data1)-train_size
train_data,test_data=data1[0:train_size,:],data1[train_size:len(data1),:1]

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	datax, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		datax.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(datax), np.array(dataY)

# %%
n_steps = 7
n_future = 1
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
x_train, y_train = create_dataset(train_data, n_steps)
x_test, y_test = create_dataset(test_data, n_steps)

# reshape input to be [samples, time steps, features] which is required for LSTM
x_train =x_train.reshape(x_train.shape[0],x_train.shape[1] , 1)
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1] , 1)

# %%
### Create the Stacked LSTM model
model=Sequential()
model.add(LSTM(60,return_sequences=True,input_shape=(n_steps,n_future)))
model.add(LSTM(60,return_sequences=True))
model.add(LSTM(60,return_sequences=True))
model.add(LSTM(60))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=500,batch_size=64,verbose=1)
# Out:
# Epoch 301/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 0.0336
# Epoch 302/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0064 - val_loss: 0.0382
# Epoch 303/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0059 - val_loss: 0.0356
# Epoch 304/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0059 - val_loss: 0.0374
# Epoch 305/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0067 - val_loss: 0.0395
# Epoch 306/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0052 - val_loss: 0.0351
# Epoch 307/500
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0071 - val_loss: 0.0387
# Epoch 308/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0346
# Epoch 309/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0046 - val_loss: 0.0327
# Epoch 310/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0325
# Epoch 311/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0313
# Epoch 312/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0309
# Epoch 313/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0048 - val_loss: 0.0309
# Epoch 314/500
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0047 - val_loss: 0.0320
# Epoch 315/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0303
# Epoch 316/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0047 - val_loss: 0.0317
# Epoch 317/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0310
# Epoch 318/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0046 - val_loss: 0.0313
# Epoch 319/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0048 - val_loss: 0.0305
# Epoch 320/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0046 - val_loss: 0.0289
# Epoch 321/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0315
# Epoch 322/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0051 - val_loss: 0.0311
# Epoch 323/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0319
# Epoch 324/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0347
# Epoch 325/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0315
# Epoch 326/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0056 - val_loss: 0.0324
# Epoch 327/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0327
# Epoch 328/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0313
# Epoch 329/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0321
# Epoch 330/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0307
# Epoch 331/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0329
# Epoch 332/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0318
# Epoch 333/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0056 - val_loss: 0.0342
# Epoch 334/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0394
# Epoch 335/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0046 - val_loss: 0.0400
# Epoch 336/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0400
# Epoch 337/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0380
# Epoch 338/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0045 - val_loss: 0.0361
# Epoch 339/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0044 - val_loss: 0.0356
# Epoch 340/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0348
# Epoch 341/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0349
# Epoch 342/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0348
# Epoch 343/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0377
# Epoch 344/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0377
# Epoch 345/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0349
# Epoch 346/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0329
# Epoch 347/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0049 - val_loss: 0.0334
# Epoch 348/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0356
# Epoch 349/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0350
# Epoch 350/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0339
# Epoch 351/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0317
# Epoch 352/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0323
# Epoch 353/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0292
# Epoch 354/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0057 - val_loss: 0.0286
# Epoch 355/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 0.0308
# Epoch 356/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0323
# Epoch 357/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0367
# Epoch 358/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0392
# Epoch 359/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0410
# Epoch 360/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0422
# Epoch 361/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0051 - val_loss: 0.0407
# Epoch 362/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0364
# Epoch 363/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0051 - val_loss: 0.0385
# Epoch 364/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0060 - val_loss: 0.0342
# Epoch 365/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0058 - val_loss: 0.0344
# Epoch 366/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0397
# Epoch 367/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0073 - val_loss: 0.0364
# Epoch 368/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 0.0379
# Epoch 369/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0414
# Epoch 370/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0053 - val_loss: 0.0370
# Epoch 371/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0352
# Epoch 372/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0049 - val_loss: 0.0356
# Epoch 373/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0332
# Epoch 374/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0047 - val_loss: 0.0370
# Epoch 375/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0056 - val_loss: 0.0361
# Epoch 376/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0378
# Epoch 377/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0044 - val_loss: 0.0416
# Epoch 378/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0049 - val_loss: 0.0384
# Epoch 379/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0057 - val_loss: 0.0374
# Epoch 380/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0377
# Epoch 381/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0320
# Epoch 382/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0066 - val_loss: 0.0334
# Epoch 383/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0369
# Epoch 384/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0062 - val_loss: 0.0321
# Epoch 385/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0062 - val_loss: 0.0345
# Epoch 386/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0385
# Epoch 387/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0049 - val_loss: 0.0352
# Epoch 388/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0358
# Epoch 389/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0382
# Epoch 390/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0063 - val_loss: 0.0346
# Epoch 391/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0066 - val_loss: 0.0353
# Epoch 392/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0051 - val_loss: 0.0412
# Epoch 393/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0059 - val_loss: 0.0384
# Epoch 394/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0385
# Epoch 395/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0396
# Epoch 396/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0047 - val_loss: 0.0367
# Epoch 397/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0372
# Epoch 398/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0381
# Epoch 399/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0347
# Epoch 400/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0065 - val_loss: 0.0367
# Epoch 401/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0428
# Epoch 402/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0055 - val_loss: 0.0406
# Epoch 403/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0410
# Epoch 404/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0419
# Epoch 405/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0381
# Epoch 406/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0063 - val_loss: 0.0421
# Epoch 407/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0421
# Epoch 408/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0398
# Epoch 409/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0063 - val_loss: 0.0418
# Epoch 410/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0429
# Epoch 411/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0053 - val_loss: 0.0377
# Epoch 412/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0049 - val_loss: 0.0362
# Epoch 413/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0379
# Epoch 414/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0380
# Epoch 415/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0385
# Epoch 416/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0396
# Epoch 417/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0406
# Epoch 418/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 0.0403
# Epoch 419/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0407
# Epoch 420/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0399
# Epoch 421/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0386
# Epoch 422/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0375
# Epoch 423/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0389
# Epoch 424/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0045 - val_loss: 0.0394
# Epoch 425/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0043 - val_loss: 0.0384
# Epoch 426/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0390
# Epoch 427/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0044 - val_loss: 0.0401
# Epoch 428/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0395
# Epoch 429/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0044 - val_loss: 0.0389
# Epoch 430/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0042 - val_loss: 0.0396
# Epoch 431/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0384
# Epoch 432/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0377
# Epoch 433/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0044 - val_loss: 0.0362
# Epoch 434/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0359
# Epoch 435/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0370
# Epoch 436/500
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0045 - val_loss: 0.0361
# Epoch 437/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0044 - val_loss: 0.0356
# Epoch 438/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0045 - val_loss: 0.0368
# Epoch 439/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0045 - val_loss: 0.0366
# Epoch 440/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0367
# Epoch 441/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0392
# Epoch 442/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0043 - val_loss: 0.0379
# Epoch 443/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0387
# Epoch 444/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0397
# Epoch 445/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0382
# Epoch 446/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0396
# Epoch 447/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0042 - val_loss: 0.0415
# Epoch 448/500
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0045 - val_loss: 0.0406
# Epoch 449/500
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0043 - val_loss: 0.0408
# Epoch 450/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0043 - val_loss: 0.0422
# Epoch 451/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 0.0434
# Epoch 452/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0446
# Epoch 453/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0463
# Epoch 454/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0447
# Epoch 455/500
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0045 - val_loss: 0.0439
# Epoch 456/500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0043 - val_loss: 0.0424
# Epoch 457/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0043 - val_loss: 0.0405
# Epoch 458/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 0.0401
# Epoch 459/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 0.0388
# Epoch 460/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0045 - val_loss: 0.0400
# Epoch 461/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0405
# Epoch 462/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0394
# Epoch 463/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0413
# Epoch 464/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0414
# Epoch 465/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0411
# Epoch 466/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0424
# Epoch 467/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0412
# Epoch 468/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0416
# Epoch 469/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0042 - val_loss: 0.0419
# Epoch 470/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0398
# Epoch 471/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0042 - val_loss: 0.0385
# Epoch 472/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0377
# Epoch 473/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0382
# Epoch 474/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0399
# Epoch 475/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0390
# Epoch 476/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0044 - val_loss: 0.0379
# Epoch 477/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0042 - val_loss: 0.0375
# Epoch 478/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0360
# Epoch 479/500
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0042 - val_loss: 0.0351
# Epoch 480/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0044 - val_loss: 0.0360
# Epoch 481/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0356
# Epoch 482/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 0.0332
# Epoch 483/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0351
# Epoch 484/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0374
# Epoch 485/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0364
# Epoch 486/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0058 - val_loss: 0.0379
# Epoch 487/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0051 - val_loss: 0.0396
# Epoch 488/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0367
# Epoch 489/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0060 - val_loss: 0.0379
# Epoch 490/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0042 - val_loss: 0.0400
# Epoch 491/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0051 - val_loss: 0.0375
# Epoch 492/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0373
# Epoch 493/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0394
# Epoch 494/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0371
# Epoch 495/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0376
# Epoch 496/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0404
# Epoch 497/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0395
# Epoch 498/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0062 - val_loss: 0.0418
# Epoch 499/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0044 - val_loss: 0.0433
# Epoch 500/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0397

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(x_train)
test_predict=model.predict(x_test)

##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

len(train_data),len(test_data)
# Out:
# (146, 79)

# %%
### Plotting 
# shift train predictions for plotting
look_back=n_steps
trainPredictPlot = np.empty_like(data1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(data1)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(data1)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(data1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len_test=len(test_data)
x_input=test_data[len_test-n_steps:].reshape(1,-1)
x_input.shape
# Out:
# (1, 7)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 3 days

lst_output=[]
forecas_day = 3
n_steps=n_steps
i=0
while(i<forecas_day):
    
    if(len(temp_input)>n_steps):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        # print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# 1 day output [[0.26837197]]
# 2 day output [[0.30988708]]

# %%
rang  = n_steps+1
rang_feature = rang+forecas_day
day_new=np.arange(1,rang)
day_pred=np.arange(rang,rang_feature)

len_data = len(data1)-n_steps
print("Len Data: ", len_data)
plt.plot(day_new, scaler.inverse_transform(data1[len_data:]))
plt.plot(day_pred, scaler.inverse_transform(lst_output))
# Out:
# Len Data:  220

# %%
df_pre=data1.tolist()
df_pre.extend(lst_output)
df_pre=scaler.inverse_transform(df_pre).tolist()

# %%
plt.plot(df_pre)
len(df_pre)
# Out:
# 228

# %%
sql = """ select * FROM  stocks_db.SET50  WHERE Symbols = "ADVANC.BK"  AND Date BETWEEN '2019-01-01' AND '2020-12-04'  """ 
data_og = pd.read_sql_query(sql, engine)
data_og
# Out:
#           Date    Symbols   Open   High    Low  Close   Adj Close      Volume
# 0   2019-01-02  ADVANC.BK  173.0  174.5  171.5  173.5  161.822723   3190700.0
# 1   2019-01-03  ADVANC.BK  174.0  176.0  172.5  172.5  160.890015   5720500.0
# 2   2019-01-04  ADVANC.BK  172.5  178.0  172.5  177.0  165.087158   7425100.0
# 3   2019-01-07  ADVANC.BK  178.0  178.0  176.5  177.0  165.087158   3662300.0
# 4   2019-01-08  ADVANC.BK  177.0  178.0  176.5  177.5  165.553497   2416100.0
# ..         ...        ...    ...    ...    ...    ...         ...         ...
# 467 2020-11-30  ADVANC.BK  179.0  180.0  175.5  175.5  175.500000  20143400.0
# 468 2020-12-01  ADVANC.BK  176.5  179.5  176.5  178.0  178.000000  12453300.0
# 469 2020-12-02  ADVANC.BK  179.5  183.0  178.5  180.0  180.000000  18803500.0
# 470 2020-12-03  ADVANC.BK  181.5  182.0  179.5  180.5  180.500000  10016400.0
# 471 2020-12-04  ADVANC.BK  181.0  182.5  179.5  181.5  181.500000   9514700.0
#
# [472 rows x 8 columns]

# %%
og_close = data_og.reset_index()['Close']
plt.plot(og_close)
len_ogclose=len(og_close)-forecas_day
data_real = og_close[len_ogclose:]
len(og_close)
# Out:
# 472

# %%
len_dfpre = len(df_pre)-forecas_day
data_pre = df_pre[len_dfpre:]
plt.plot(data_pre)
print(len(data_pre))
data_pre
# Out:
# 3
# [[182.29590487480164], [184.22371438145638], [186.42401531338692]]

# %%
plt.plot(data_real)
print(len(data_real))
data_real=data_real.tolist()
data_real
# Out:
# 3
# [180.0, 180.5, 181.5]

# %%
rsme_lstm=math.sqrt(mean_squared_error(data_real,data_pre)) 
print("RSME: ",rsme_lstm)
# Out:
# RSME:  3.802768938342683
